# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('dataset.csv')
#read the csv into a pandas dataframe
#print(df.head[5])
df.head()
# Out:
#         ID        Country  AncientComponent1  AncientComponent2  \
# 0   12885A  UnitedKingdom              0.005              0.000
# 1   NO3423  UnitedKingdom              0.126              0.101
# 2  RISE568  CzechRepublic              0.000              0.000
# 3   12881A  UnitedKingdom              0.044              0.061
# 4  RISE569  CzechRepublic              0.000              0.060
#
#    AncientComponent3  AncientComponent4  AncientComponent5  ModernComponent1  \
# 0              0.000              0.000              0.000             0.000
# 1              0.007              0.089              0.025             0.032
# 2              0.011              0.067              0.228             0.014
# 3              0.040              0.052              0.000             0.007
# 4              0.077              0.042              0.000             0.038
#
#    ModernComponent2  ModernComponent3  DateBP
# 0             0.995             0.000  1165.0
# 1             0.613             0.005  1170.0
# 2             0.672             0.008  1200.0
# 3             0.770             0.025  1232.0
# 4             0.774             0.009  1235.0

# %%
df=df.values
#converting the dataframe object into a numpy array
#print(df)

# %%
data=df[:,2:10]
target=df[:,10]

# %%
target=np.reshape(target, (-1,1))

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data, train_target, test_target = train_test_split(data,target,test_size=0.1)

# %%
from sklearn.linear_model import LinearRegression

# %%
clsfr=LinearRegression()

# %%
clsfr.fit(train_data,train_target)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
result=clsfr.predict(test_data)

# %%
from sklearn.metrics import r2_score

# %%
r2_value=r2_score(test_target,result)

# %%
#print("Cofficent =>"+clsfr.coef_)
#print("Intercept =>"+clsfr.intercept_)
print('r2_score:',r2_value)
# Out:
# r2_score: 0.41403184271588467

# %%
print('Actual value:',test_target[0:10])
print('Predicted value',result[0:10])
# Out:
# Actual value: [[4200.0]
#  [4300.0]
#  [3545.0]
#  [7698.0]
#  [4375.0]
#  [4310.0]
#  [7351.0]
#  [4740.0]
#  [4843.0]
#  [4495.0]]
# Predicted value [[5162.92827912]
#  [4574.15633355]
#  [4274.53434279]
#  [6244.96553474]
#  [3816.40750691]
#  [3898.67362701]
#  [6161.09364821]
#  [4854.50526301]
#  [3243.93736571]
#  [3347.77452158]]

# %%
from matplotlib import pyplot as plt
plt.plot(list(range(50)), result[0:50])
plt.plot(list(range(50)),test_target[0:50])
plt.show()

# %%
from matplotlib import pyplot as plt
plt.plot(list(range(100)), result[0:100])
plt.plot(list(range(100)),test_target[0:100])
plt.show()
